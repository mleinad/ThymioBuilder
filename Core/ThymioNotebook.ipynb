# %%
import math
import time
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
import sys, os

# Path to the project root (one level up from Core/)
project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Added to path:", project_root)
# Out:
# Added to path: c:\Users\danie\OneDrive\Documentos\FCUL\MobileRobots\ThymioBuilder

# %%
def wait_for_performed(timeout=10.0):
    import time
    start = time.time()
    while time.time() - start < timeout:
        data = get_event_data("performed")
        print(data + " waiting...")
        if data[0] == 1:
            return data
        time.sleep(0.05)  # short pause before polling again
    return None

# %%
send_event("forward")

# %%
send_event("backwards")

# %%
# Move half a cell forward
send_event("half_forward")
time.sleep(2)               #do callback events instead!!!!!
# Rotate right
send_event("right")
time.sleep(2)
# Move half a cell backward
send_event("half_back")

# %%
# Move half a cell forward
send_event("half_forward")
time.sleep(2)               #do callback events instead!!!!!
# Rotate right
send_event("left")
time.sleep(2)
# Move half a cell backward
send_event("half_back")

# %%
def move_forward():
    print("Moving Forward")
    send_event("forward")

def move_backward():
    send_event("backwards")
    print("Moving Backward")

def rotate_right():
    print("Rotating Right")
    # Move half a cell forward
    send_event("half_forward")
    time.sleep(2)               #do callback events instead!!!!!
    # Rotate right
    send_event("right")
    time.sleep(2)
    # Move half a cell backward
    send_event("half_back")

def rotate_left():
    # Move half a cell forward
    send_event("half_forward")
    time.sleep(2)               #do callback events instead!!!!!
    # Rotate right
    send_event("left")
    time.sleep(2)
    # Move half a cell backward
    send_event("half_back")
    print("Rotating Left")

def find_block():
    print("Finding Block")

# %%
from Core.ActionQueue import ActionQueue
from Environment.Block_Manager import BlockManager
from Environment.Grid_Map import GridMap
from PathPlanner import PathPlanner

block_manager = None
planner =   None
action_queue = None


def set_up_envioronment():

    grid = GridMap(width_cells=20, height_cells=15, cell_size=50)
   
    global block_manager, planner, action_queue
    #block_manager = BlockManager(grid)
    #block_manager.add_block("cube1", BlockManager.Block(7, 7, 1, 1))
    planner = PathPlanner(grid)
    action_queue = ActionQueue()

    robot_start = (0, 0)
    robot_angle = 0  # 0=East

    block_start = (3,2)  # Where the block is now
    block_goal = (3,4)  # Where you want it to go

    # 5. Generate ALL commands
    print(f"Generating mission from {block_start} to {block_goal}...")
    #mission_queue = planner.generate_mission(robot_start, robot_angle, block_start, block_goal)

#    for cmd in mission_queue:
#        action_queue.add(cmd)

    action_queue.add_sequence(["F", "F", "F", "TR", "F"])  # Go to Block and Pick

    print("Final Command Queue:")
    action_queue.print_queue()

# %%
set_up_envioronment()

global action_queue

action_queue.print_queue()

while True:
        if action_queue.has_next():
                action = action_queue.next()
                print(f"Executing: {action}")

                if action == "F":
                    move_forward()
                    time.sleep(3)
                elif action == "B":
                    move_backward()
                    time.sleep(3)
                elif action == "TR":
                    rotate_right()
                    time.sleep(3)
                elif action == "TL":
                    rotate_left()
                    time.sleep(3)
                elif action == "PB":
                    find_block()
                else:
                    print(f"Unknown action: {action}")
# Out:
# Generating mission from (3, 2) to (3, 4)...
# Final Command Queue:
# F -> F -> F -> TR -> F
# F -> F -> F -> TR -> F
# Executing: F
# Moving Forward
# Executing: F
# Moving Forward
# Executing: F
# Moving Forward
# Executing: TR
# Rotating Right
# Executing: F
# Moving Forward

# %%
await tdmclient.notebook.stop()
